# %% [markdown]
# ### 1. Data Collecting

# %% [markdown]
# Tahapan ini ada pada `scraping.ipynb` yang dimana kita mengambil dataset sejumlah 12.000 review dari google play store menggunakan `google-play-scraper`

# %% [markdown]
# ### 2. Data Preprocessing

# %% [markdown]
# #### a. Data Info

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pandas as pd

# %%
df = pd.read_csv('./dataset/reviews.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reviewId  12000 non-null  object
#  1   userName  12000 non-null  object
#  2   content   12000 non-null  object
#  3   score     12000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 375.1+ KB

# %% [markdown]
# #### b. Data Sentiment
#
# Di kita akan menambahkan kolom baru pada DataFrame yaitu `sentiments` untuk membagi kelompok dari review. 0 untuk `score <= 2` dan 1 untuk `score >= 3`

# %%
df['sentiments'] = df.score.apply(lambda x: 0 if x in [1, 2] else 1)

# %% [markdown]
# ### 3. Data Analysis and Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Visualisasi Pie terhadapat sentiment

# %%
plt.figure(figsize=(15,7))
# sentimen = df.dropna(subset=['sentiments']).sort_values(by=['sentiments'])['sentiments'].unique()
total = df.groupby(['sentiments'])['score'].count()
plt.pie(total, labels=(["Negatif", "Positif"]), autopct='%.1f%%', startangle = 120, shadow = True)
plt.title('Sentimen Game')
plt.show()

# %% [markdown]
# #### Visualisasi Pie terhadapat Rating

# %%
plt.figure(figsize=(15,7))
rating = df.dropna(subset=['score']).sort_values(by=['score'])['score'].unique()
total = df.groupby(['score'])['reviewId'].count()
plt.pie(total, labels=rating, autopct='%.1f%%', startangle = 120, shadow = True)
plt.title('Rating Game')
plt.show()

# %% [markdown]
# #### Visualisasi bar terhadapat Rating dan jumlah penggunaan game

# %%
score= df.dropna(subset=['score']).sort_values(by=['score'])['score'].unique()
total = df.groupby(['score'])['reviewId'].count()
plt.bar(score, total, color='red')
# plt.title('')
plt.xlabel('Rating', fontsize=11)
plt.ylabel('Total Pengguna Game', fontsize=11)
plt.grid()
plt.show()

# %% [markdown]
# ### 4. Data Modeling

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
tokenizer = Tokenizer(oov_token="<OOV>")

# %%
x_train, x_test, y_train, y_test = train_test_split(df['content'], df['sentiments'], test_size=0.4)

# %%
import numpy as np
training_sentences = []
training_labels = []
testing_sentences = []
testing_labels = []
for row in x_train:
    training_sentences.append(str(row))
for row in y_train:
    training_labels.append(row)
for row in x_test:
    testing_sentences.append(str(row))
for row in y_test:
    testing_labels.append(row)

# %%
vocab_size = 40000
embedding_dim = 16
max_length = 120
trunc_type = 'post'
oov_tok = '<OOV>'
padding_type = 'post'

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

word_index
# Out:
# {'<OOV>': 1,
#  'game': 2,
#  'bagus': 3,
#  'nya': 4,
#  'di': 5,
#  'saya': 6,
#  'dan': 7,
#  'ini': 8,
#  'yang': 9,
#  'bisa': 10,
#  'tapi': 11,
#  'sangat': 12,
#  'untuk': 13,
#  'banget': 14,
#  'seru': 15,
#  'yg': 16,
#  'tolong': 17,
#  'main': 18,
#  'aku': 19,
#  'hp': 20,
#  'ada': 21,
#  'the': 22,
#  'keren': 23,
#  'genshin': 24,
#  'lagi': 25,
#  'gamenya': 26,
#  'tidak': 27,
#  'gak': 28,
#  'buat': 29,
#  'update': 30,
#  'grafik': 31,
#  'banyak': 32,
#  'dari': 33,
#  'kasih': 34,
#  'download': 35,
#  'i': 36,
#  'aja': 37,
#  'udah': 38,
#  'good': 39,
#  'juga': 40,
#  'jadi': 41,
#  'ga': 42,
#  'ya': 43,
#  'bintang': 44,
#  'suka': 45,
#  'mantap': 46,
#  'karakter': 47,
#  'gacha': 48,
#  'gw': 49,
#  'mau': 50,
#  'sudah': 51,
#  'lah': 52,
#  'sama': 53,
#  'impact': 54,
#  'sih': 55,
#  'itu': 56,
#  'dengan': 57,
#  '1': 58,
#  'kalo': 59,
#  '5': 60,
#  'lama': 61,
#  'karena': 62,
#  'nice': 63,
#  'lebih': 64,
#  'data': 65,
#  'and': 66,
#  'padahal': 67,
#  'ku': 68,
#  'story': 69,
#  'hoyoverse': 70,
#  'to': 71,
#  'ke': 72,
#  'masih': 73,
#  'sekali': 74,
#  '3': 75,
#  'mihoyo': 76,
#  'kenapa': 77,
#  'rate': 78,
#  'gk': 79,
#  'susah': 80,
#  'menarik': 81,
#  'kalau': 82,
#  'this': 83,
#  'cuma': 84,
#  'harus': 85,
#  'is': 86,
#  'pas': 87,
#  'terlalu': 88,
#  'terus': 89,
#  'baru': 90,
#  'semoga': 91,
#  'bikin': 92,
#  'dapat': 93,
#  'player': 94,
#  '2': 95,
#  'dong': 96,
#  'jangan': 97,
#  'quest': 98,
#  'kok': 99,
#  'for': 100,
#  'best': 101,
#  'bug': 102,
#  'udh': 103,
#  'dapet': 104,
#  'pity': 105,
#  'dah': 106,
#  'in': 107,
#  'gua': 108,
#  'semua': 109,
#  'akun': 110,
#  'please': 111,
#  'artefak': 112,
#  'mohon': 113,
#  'event': 114,
#  'cerita': 115,
#  'gb': 116,
#  'a': 117,
#  'apa': 118,
#  'fitur': 119,
#  'kali': 120,
#  'you': 121,
#  'bermain': 122,
#  'atau': 123,
#  'karna': 124,
#  'makin': 125,
#  'lain': 126,
#  'terbaik': 127,
#  'pernah': 128,
#  'berat': 129,
#  'malah': 130,
#  'saat': 131,
#  'pelit': 132,
#  'sering': 133,
#  'of': 134,
#  'it': 135,
#  'perbaiki': 136,
#  'biar': 137,
#  'ok': 138,
#  'my': 139,
#  'gg': 140,
#  'sumeru': 141,
#  'ram': 142,
#  'gameplay': 143,
#  'masuk': 144,
#  'saja': 145,
#  'lag': 146,
#  'kurang': 147,
#  'sekarang': 148,
#  'besar': 149,
#  'hanya': 150,
#  'so': 151,
#  'kentang': 152,
#  'ni': 153,
#  'login': 154,
#  'hadiah': 155,
#  'cuman': 156,
#  'seperti': 157,
#  'ampas': 158,
#  'but': 159,
#  'segi': 160,
#  'selalu': 161,
#  'dalam': 162,
#  'dulu': 163,
#  'bgt': 164,
#  'off': 165,
#  'b5': 166,
#  'primo': 167,
#  'paling': 168,
#  'kalian': 169,
#  'alur': 170,
#  'map': 171,
#  'android': 172,
#  'up': 173,
#  'grafiknya': 174,
#  'mobile': 175,
#  'me': 176,
#  'lumayan': 177,
#  'sampai': 178,
#  'resin': 179,
#  'membuat': 180,
#  'waktu': 181,
#  'penyimpanan': 182,
#  'like': 183,
#  'orang': 184,
#  'baik': 185,
#  '👍': 186,
#  'mulu': 187,
#  'developer': 188,
#  'gem': 189,
#  'akan': 190,
#  'terimakasih': 191,
#  'give': 192,
#  'kan': 193,
#  'satu': 194,
#  'very': 195,
#  'ny': 196,
#  'kita': 197,
#  'cukup': 198,
#  'tahun': 199,
#  'setelah': 200,
#  'nih': 201,
#  'walaupun': 202,
#  'hd': 203,
#  '4': 204,
#  'no': 205,
#  'deh': 206,
#  'belum': 207,
#  'lancar': 208,
#  'awal': 209,
#  'masalah': 210,
#  'gitu': 211,
#  'agar': 212,
#  'top': 213,
#  'mungkin': 214,
#  'setiap': 215,
#  'jelek': 216,
#  'coba': 217,
#  'world': 218,
#  'anniversary': 219,
#  'menyenangkan': 220,
#  'nahida': 221,
#  'on': 222,
#  'agak': 223,
#  'character': 224,
#  'hari': 225,
#  'hapus': 226,
#  'kecewa': 227,
#  'parah': 228,
#  'love': 229,
#  'masa': 230,
#  'klo': 231,
#  'semakin': 232,
#  'sistem': 233,
#  'sampe': 234,
#  'open': 235,
#  'tpi': 236,
#  'device': 237,
#  'sedikit': 238,
#  'play': 239,
#  'saran': 240,
#  'min': 241,
#  'mb': 242,
#  'that': 243,
#  '0': 244,
#  'pokoknya': 245,
#  'si': 246,
#  'can': 247,
#  'bagi': 248,
#  'size': 249,
#  'have': 250,
#  'oke': 251,
#  'soalnya': 252,
#  'kalah': 253,
#  'diperbaiki': 254,
#  'pake': 255,
#  'ping': 256,
#  'kayak': 257,
#  'sendiri': 258,
#  'wibu': 259,
#  'ceritanya': 260,
#  'kadang': 261,
#  'ngelag': 262,
#  'sy': 263,
#  'mendapatkan': 264,
#  'memori': 265,
#  'misi': 266,
#  'pengen': 267,
#  'punya': 268,
#  'langsung': 269,
#  'tambahin': 270,
#  'sulit': 271,
#  'kek': 272,
#  'tetap': 273,
#  'drop': 274,
#  'g': 275,
#  'kuat': 276,
#  'domain': 277,
#  'server': 278,
#  '10': 279,
#  'f2p': 280,
#  'banner': 281,
#  'tau': 282,
#  'dpt': 283,
#  'primogem': 284,
#  'versi': 285,
#  'sayang': 286,
#  'ingin': 287,
#  'loading': 288,
#  'tiba': 289,
#  'pada': 290,
#  'overall': 291,
#  'terima': 292,
#  'yah': 293,
#  'bener': 294,
#  'adalah': 295,
#  'bosen': 296,
#  'maen': 297,
#  'keluar': 298,
#  'para': 299,
#  'fix': 300,
#  'more': 301,
#  'just': 302,
#  'menjadi': 303,
#  'grafis': 304,
#  'gede': 305,
#  'zhongli': 306,
#  'biasa': 307,
#  'doang': 308,
#  'beberapa': 309,
#  'mainkan': 310,
#  'char': 311,
#  'lu': 312,
#  'pemain': 313,
#  'pun': 314,
#  'make': 315,
#  'kasi': 316,
#  'ar': 317,
#  'walau': 318,
#  'dll': 319,
#  'tp': 320,
#  'reward': 321,
#  'an': 322,
#  'close': 323,
#  '🗿': 324,
#  'asik': 325,
#  'jaringan': 326,
#  'with': 327,
#  'qiqi': 328,
#  'cocok': 329,
#  'be': 330,
#  'tambah': 331,
#  'pihak': 332,
#  'force': 333,
#  'pls': 334,
#  'ulang': 335,
#  'pc': 336,
#  'tinggi': 337,
#  'mudah': 338,
#  'nggak': 339,
#  'not': 340,
#  'hoyovers': 341,
#  'panas': 342,
#  'gue': 343,
#  'tetapi': 344,
#  'apalagi': 345,
#  'support': 346,
#  'cepat': 347,
#  '4no': 348,
#  'patah': 349,
#  'nge': 350,
#  'mana': 351,
#  'anime': 352,
#  'penuh': 353,
#  'enak': 354,
#  'frame': 355,
#  'full': 356,
#  'butuh': 357,
#  'or': 358,
#  'hard': 359,
#  'wangy': 360,
#  'maaf': 361,
#  'anda': 362,
#  'petualangan': 363,
#  'dunia': 364,
#  'burik': 365,
#  'mulai': 366,
#  'are': 367,
#  'bukan': 368,
#  'pakai': 369,
#  '50': 370,
#  'end': 371,
#  'supaya': 372,
#  'ketika': 373,
#  'baguss': 374,
#  'pasti': 375,
#  "it's": 376,
#  'd': 377,
#  'rating': 378,
#  'hilang': 379,
#  'ukuran': 380,
#  'kaya': 381,
#  'senjata': 382,
#  'makasih': 383,
#  'if': 384,
#  'hal': 385,
#  'gimana': 386,
#  'konten': 387,
#  'menurut': 388,
#  'rpg': 389,
#  'semuanya': 390,
#  'mata': 391,
#  'bet': 392,
#  'v': 393,
#  'datanya': 394,
#  'males': 395,
#  '8': 396,
#  'dikit': 397,
#  'waifu': 398,
#  'because': 399,
#  'geme': 400,
#  'tombol': 401,
#  'tambahkan': 402,
#  'musuh': 403,
#  'fps': 404,
#  'jg': 405,
#  'kata': 406,
#  'menang': 407,
#  'lawan': 408,
#  'jika': 409,
#  'gim': 410,
#  'get': 411,
#  'hoki': 412,
#  'gara': 413,
#  'merah': 414,
#  'sinyal': 415,
#  'controller': 416,
#  'bosan': 417,
#  'really': 418,
#  'wifi': 419,
#  'bulan': 420,
#  'luar': 421,
#  'ramah': 422,
#  'sumpah': 423,
#  'farming': 424,
#  'sampah': 425,
#  'amat': 426,
#  'skip': 427,
#  'hampir': 428,
#  'rata': 429,
#  'habis': 430,
#  'mending': 431,
#  'atas': 432,
#  'apakah': 433,
#  'mantep': 434,
#  'will': 435,
#  'bang': 436,
#  'dev': 437,
#  'liat': 438,
#  'beri': 439,
#  'plis': 440,
#  'kedepannya': 441,
#  'berikan': 442,
#  'memory': 443,
#  'mainin': 444,
#  'nanti': 445,
#  'ever': 446,
#  'archon': 447,
#  'patch': 448,
#  'nyaman': 449,
#  'wow': 450,
#  'why': 451,
#  'permainan': 452,
#  'gachanya': 453,
#  'spiral': 454,
#  'ama': 455,
#  'low': 456,
#  'account': 457,
#  'minimal': 458,
#  'nunggu': 459,
#  'seruu': 460,
#  'even': 461,
#  'anj': 462,
#  'we': 463,
#  'tiap': 464,
#  'damage': 465,
#  'abis': 466,
#  'selesai': 467,
#  'happy': 468,
#  'cuy': 469,
#  'semangat': 470,
#  'storage': 471,
#  'memainkan': 472,
#  'pertama': 473,
#  'cara': 474,
#  'level': 475,
#  "don't": 476,
#  'dikasih': 477,
#  'monster': 478,
#  'cool': 479,
#  'bgs': 480,
#  'ngasih': 481,
#  'aj': 482,
#  'lalu': 483,
#  'pensi': 484,
#  'weapon': 485,
#  'want': 486,
#  'minta': 487,
#  'lite': 488,
#  'boleh': 489,
#  'namun': 490,
#  'wajib': 491,
#  'great': 492,
#  'mainnya': 493,
#  'ah': 494,
#  'terbaru': 495,
#  'sebelum': 496,
#  'tetep': 497,
#  'eh': 498,
#  'memanjakan': 499,
#  'memuaskan': 500,
#  'hack': 501,
#  'balik': 502,
#  'kembali': 503,
#  'kebanyakan': 504,
#  'hehe': 505,
#  't': 506,
#  'there': 507,
#  'knp': 508,
#  'kazuha': 509,
#  'star': 510,
#  '6': 511,
#  'thank': 512,
#  'trus': 513,
#  'beli': 514,
#  'hu': 515,
#  'meledak': 516,
#  'raiden': 517,
#  'memang': 518,
#  'lima': 519,
#  'perlu': 520,
#  'puzzle': 521,
#  'salah': 522,
#  'venti': 523,
#  'nyesel': 524,
#  'kepada': 525,
#  'desain': 526,
#  'indonesia': 527,
#  'telah': 528,
#  'trs': 529,
#  'keqing': 530,
#  'semenjak': 531,
#  'buka': 532,
#  'terutama': 533,
#  'tuh': 534,
#  'apk': 535,
#  'dimainkan': 536,
#  'pull': 537,
#  'rilis': 538,
#  'segera': 539,
#  'sekian': 540,
#  'spek': 541,
#  'arte': 542,
#  'jalan': 543,
#  'endgame': 544,
#  'from': 545,
#  'always': 546,
#  'bad': 547,
#  'all': 548,
#  'begitu': 549,
#  'fun': 550,
#  '20': 551,
#  'benar': 552,
#  'adventure': 553,
#  'thanks': 554,
#  'ngotak': 555,
#  'luas': 556,
#  'puas': 557,
#  'rendah': 558,
#  'bakal': 559,
#  "i'm": 560,
#  'kecil': 561,
#  'indah': 562,
#  'kami': 563,
#  'its': 564,
#  'buruk': 565,
#  'jelas': 566,
#  'jam': 567,
#  'sebelumnya': 568,
#  '100': 569,
#  'aplikasi': 570,
#  'bgus': 571,
#  'menunggu': 572,
#  'def': 573,
#  'ganyu': 574,
#  'when': 575,
#  'gini': 576,
#  'akhirnya': 577,
#  'gabisa': 578,
#  'aniv': 579,
#  'next': 580,
#  'naik': 581,
#  'lgi': 582,
#  'bahkan': 583,
#  'eror': 584,
#  'tao': 585,
#  'pusing': 586,
#  'suruh': 587,
#  'enjoy': 588,
#  'as': 589,
#  'kena': 590,
#  'nyari': 591,
#  'primogems': 592,
#  'gila': 593,
#  'kuota': 594,
#  'storynya': 595,
#  'katanya': 596,
#  'terjadi': 597,
#  'one': 598,
#  'menggunakan': 599,
#  'time': 600,
#  'jgn': 601,
#  'kurangi': 602,
#  'mati': 603,
#  'need': 604,
#  'sesuai': 605,
#  'moga': 606,
#  'free': 607,
#  'sebenarnya': 608,
#  'melihat': 609,
#  'oh': 610,
#  'your': 611,
#  'karakternya': 612,
#  'santai': 613,
#  'bilang': 614,
#  'do': 615,
#  'wkwk': 616,
#  'yaa': 617,
#  'again': 618,
#  'cmn': 619,
#  'cari': 620,
#  'hero': 621,
#  'y': 622,
#  'graphic': 623,
#  '7': 624,
#  'ajg': 625,
#  'berharap': 626,
#  'setting': 627,
#  'perbanyak': 628,
#  '200': 629,
#  'add': 630,
#  'perfect': 631,
#  'paimon': 632,
#  'tentang': 633,
#  'yaitu': 634,
#  'skill': 635,
#  'selama': 636,
#  'playing': 637,
#  'ganti': 638,
#  'jauh': 639,
#  'mmorpg': 640,
#  'render': 641,
#  'muncul': 642,
#  'gratis': 643,
#  'still': 644,
#  'lg': 645,
#  'sebagai': 646,
#  'nilou': 647,
#  '😁': 648,
#  'emang': 649,
#  'kasian': 650,
#  'jd': 651,
#  'phone': 652,
#  'ruang': 653,
#  'capek': 654,
#  'also': 655,
#  "can't": 656,
#  'ayo': 657,
#  'item': 658,
#  'pliss': 659,
#  'teman': 660,
#  'updatenya': 661,
#  'new': 662,
#  'musik': 663,
#  'berkembang': 664,
#  'hoyo': 665,
#  'bansos': 666,
#  'wish': 667,
#  'much': 668,
#  'forno': 669,
#  'jdi': 670,
#  'selain': 671,
#  'teki': 672,
#  'kekurangan': 673,
#  'ad': 674,
#  'upgrade': 675,
#  'bos': 676,
#  'kendala': 677,
#  'turunin': 678,
#  'cyno': 679,
#  'too': 680,
#  'sejak': 681,
#  'harap': 682,
#  'now': 683,
#  'error': 684,
#  'hape': 685,
#  'lainnya': 686,
#  'selanjutnya': 687,
#  'pengguna': 688,
#  'lupa': 689,
#  'sya': 690,
#  'dri': 691,
#  'snapdragon': 692,
#  'loh': 693,
#  'senang': 694,
#  'mengecewakan': 695,
#  'bagian': 696,
#  'asia': 697,
#  'games': 698,
#  'chara': 699,
#  'boss': 700,
#  'sukses': 701,
#  '🥰': 702,
#  'memiliki': 703,
#  'teka': 704,
#  'lo': 705,
#  'memakan': 706,
#  'bingung': 707,
#  'about': 708,
#  'fantasy': 709,
#  'anniv': 710,
#  'material': 711,
#  'sia': 712,
#  'explore': 713,
#  'amazing': 714,
#  'handphone': 715,
#  'op': 716,
#  'pokok': 717,
#  'nerf': 718,
#  'terkadang': 719,
#  'pemandangan': 720,
#  '60': 721,
#  'ayaka': 722,
#  'gpp': 723,
#  'win': 724,
#  'bngt': 725,
#  'tanpa': 726,
#  'elit': 727,
#  'internet': 728,
#  'stabil': 729,
#  'mendukung': 730,
#  'demi': 731,
#  'bagusss': 732,
#  'sempurna': 733,
#  'permudah': 734,
#  'naikin': 735,
#  'yae': 736,
#  'meskipun': 737,
#  'tempat': 738,
#  'internal': 739,
#  'ngga': 740,
#  'u': 741,
#  'honkai': 742,
#  'at': 743,
#  '2nd': 744,
#  'ampe': 745,
#  'ngeleg': 746,
#  'pengalaman': 747,
#  'membosankan': 748,
#  'anak': 749,
#  '80': 750,
#  'berhenti': 751,
#  'dimainin': 752,
#  'ghensin': 753,
#  'inazuma': 754,
#  'b': 755,
#  'tof': 756,
#  'kamu': 757,
#  'tu': 758,
#  'anjay': 759,
#  'abyss': 760,
#  'gensin': 761,
#  'tower': 762,
#  'cantik': 763,
#  'content': 764,
#  'btw': 765,
#  'kapasitas': 766,
#  'though': 767,
#  'gamepad': 768,
#  'ter': 769,
#  'yh': 770,
#  'ditambah': 771,
#  'kaga': 772,
#  'dh': 773,
#  'spam': 774,
#  'npc': 775,
#  'hope': 776,
#  'mode': 777,
#  'cepet': 778,
#  'aneh': 779,
#  'coop': 780,
#  'sini': 781,
#  'kuning': 782,
#  "i've": 783,
#  'gud': 784,
#  'animasi': 785,
#  'spin': 786,
#  'pemula': 787,
#  'mc': 788,
#  'pokonya': 789,
#  'rumput': 790,
#  'kurangin': 791,
#  'berapa': 792,
#  '12': 793,
#  'jujur': 794,
#  'serta': 795,
#  'temen': 796,
#  'job': 797,
#  '4gb': 798,
#  'fav': 799,
#  'mantapp': 800,
#  'tinggal': 801,
#  'woi': 802,
#  'file': 803,
#  'pula': 804,
#  'kapan': 805,
#  'better': 806,
#  'kualitas': 807,
#  'perangkat': 808,
#  'pindah': 809,
#  'secara': 810,
#  'tersebut': 811,
#  'keamanan': 812,
#  'medium': 813,
#  '70': 814,
#  'dua': 815,
#  'tdk': 816,
#  'memberikan': 817,
#  'kagak': 818,
#  'sedang': 819,
#  'bantu': 820,
#  '🙏': 821,
#  'ternyata': 822,
#  '200mb': 823,
#  'masalahnya': 824,
#  'battle': 825,
#  'version': 826,
#  '9': 827,
#  'rerun': 828,
#  'bangett': 829,
#  'memo': 830,
#  'rank': 831,
#  'sm': 832,
#  'babi': 833,
#  'ringan': 834,
#  'wah': 835,
#  'kecuali': 836,
#  'normal': 837,
#  '90': 838,
#  '128': 839,
#  'apaan': 840,
#  'aniversary': 841,
#  'mahal': 842,
#  'instal': 843,
#  'laptop': 844,
#  'sedih': 845,
#  'stat': 846,
#  'lot': 847,
#  'stuck': 848,
#  'suara': 849,
#  'mendapat': 850,
#  'lihat': 851,
#  'mantab': 852,
#  'sehingga': 853,
#  'sayangnya': 854,
#  'memainkannya': 855,
#  'pulang': 856,
#  'dialog': 857,
#  'yoimiya': 858,
#  'kedepan': 859,
#  'kelamaan': 860,
#  'mereka': 861,
#  'aman': 862,
#  'sizenya': 863,
#  'hutao': 864,
#  'elite': 865,
#  'terbatas': 866,
#  'akhir': 867,
#  'back': 868,
#  'go': 869,
#  'build': 870,
#  'ribet': 871,
#  'youtube': 872,
#  'unduh': 873,
#  'merasakan': 874,
#  '😭': 875,
#  'kemarin': 876,
#  'lewat': 877,
#  'buff': 878,
#  'nambah': 879,
#  'after': 880,
#  'been': 881,
#  'pdhl': 882,
#  'iya': 883,
#  'graphics': 884,
#  'makan': 885,
#  'ukurannya': 886,
#  'banyakin': 887,
#  'hijau': 888,
#  'penting': 889,
#  'sub': 890,
#  'ngeframe': 891,
#  'gi': 892,
#  'panjang': 893,
#  'menyukai': 894,
#  'layar': 895,
#  'miko': 896,
#  'tunggu': 897,
#  'got': 898,
#  'sungguh': 899,
#  'hadiahnya': 900,
#  'uninstall': 901,
#  'played': 902,
#  'wangi': 903,
#  'koneksi': 904,
#  'sedangkan': 905,
#  'ko': 906,
#  'dlu': 907,
#  'dapetin': 908,
#  'auto': 909,
#  'bs': 910,
#  'cok': 911,
#  'rng': 912,
#  'anjir': 913,
#  'kontol': 914,
#  'xiao': 915,
#  'kyk': 916,
#  'well': 917,
#  'log': 918,
#  'gagal': 919,
#  'dimana': 920,
#  '👌': 921,
#  'optimalkan': 922,
#  'dgn': 923,
#  'terakhir': 924,
#  'bismillah': 925,
#  'benerin': 926,
#  'payah': 927,
#  'ketagihan': 928,
#  'cakep': 929,
#  'kembangkan': 930,
#  'artifact': 931,
#  'video': 932,
#  'gampang': 933,
#  '🥲': 934,
#  "story'": 935,
#  'disini': 936,
#  'skin': 937,
#  'dia': 938,
#  'players': 939,
#  'bakalan': 940,
#  '8gb': 941,
#  'cape': 942,
#  'sip': 943,
#  'pay': 944,
#  'kebawah': 945,
#  'intinya': 946,
#  'mengalami': 947,
#  'selamat': 948,
#  'jarang': 949,
#  'blessing': 950,
#  'emosi': 951,
#  'sakit': 952,
#  'years': 953,
#  'gtu': 954,
#  'utk': 955,
#  'dear': 956,
#  'mabar': 957,
#  'only': 958,
#  'mayan': 959,
#  'us': 960,
#  'daily': 961,
#  'otak': 962,
#  'guys': 963,
#  'donlod': 964,
#  'screen': 965,
#  'tolol': 966,
#  'diatas': 967,
#  'traveler': 968,
#  'soal': 969,
#  'skrg': 970,
#  '15': 971,
#  'kokomi': 972,
#  'co': 973,
#  'voice': 974,
#  'usah': 975,
#  'duit': 976,
#  'segitu': 977,
#  'smartphone': 978,
#  '16': 979,
#  'teks': 980,
#  'guna': 981,
#  'bawah': 982,
#  'rame': 983,
#  'dmg': 984,
#  'tambahan': 985,
#  'tak': 986,
#  'merasa': 987,
#  'bugnya': 988,
#  'poco': 989,
#  'asu': 990,
#  'stars': 991,
#  'farm': 992,
#  'ngulang': 993,
#  'asli': 994,
#  'crit': 995,
#  'same': 996,
#  'kanan': 997,
#  '30': 998,
#  'am': 999,
#  'dikarenakan': 1000,
#  ...}

# %%
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences, maxlen=max_length, truncating=trunc_type)
testing_sentences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sentences, maxlen=max_length)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim,       input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 120, 16)           640000
#
#  global_average_pooling1d_3   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_6 (Dense)             (None, 6)                 102
#
#  dense_7 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 640,109
# Trainable params: 640,109
# Non-trainable params: 0
# _________________________________________________________________

# %%
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)
testing_labels_final
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
num_epochs = 20
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.1863 - accuracy: 0.9247 - val_loss: 0.3708 - val_accuracy: 0.8481
# Epoch 2/20
# 225/225 [==============================] - 1s 6ms/step - loss: 0.1784 - accuracy: 0.9297 - val_loss: 0.3729 - val_accuracy: 0.8487
# Epoch 3/20
# 225/225 [==============================] - 1s 6ms/step - loss: 0.1709 - accuracy: 0.9326 - val_loss: 0.3860 - val_accuracy: 0.8421
# Epoch 4/20
# 225/225 [==============================] - 1s 7ms/step - loss: 0.1641 - accuracy: 0.9329 - val_loss: 0.3779 - val_accuracy: 0.8485
# Epoch 5/20
# 225/225 [==============================] - 1s 7ms/step - loss: 0.1572 - accuracy: 0.9389 - val_loss: 0.3844 - val_accuracy: 0.8452
# Epoch 6/20
# 225/225 [==============================] - 1s 6ms/step - loss: 0.1518 - accuracy: 0.9406 - val_loss: 0.3883 - val_accuracy: 0.8494
# Epoch 7/20
# 225/225 [==============================] - 1s 6ms/step - loss: 0.1452 - accuracy: 0.9442 - val_loss: 0.3940 - val_accuracy: 0.8446
# Epoch 8/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.1406 - accuracy: 0.9453 - val_loss: 0.3964 - val_accuracy: 0.8458
# Epoch 9/20
# 225/225 [==============================] - 1s 6ms/step - loss: 0.1359 - accuracy: 0.9497 - val_loss: 0.4081 - val_accuracy: 0.8406
# Epoch 10/20
# 225/225 [==============================] - 1s 6ms/step - loss: 0.1309 - accuracy: 0.9503 - val_loss: 0.4066 - val_accuracy: 0.8475
# Epoch 11/20
# 225/225 [==============================] - 1s 7ms/step - loss: 0.1267 - accuracy: 0.9532 - val_loss: 0.4119 - val_accuracy: 0.8425
# Epoch 12/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.1210 - accuracy: 0.9558 - val_loss: 0.4158 - val_accuracy: 0.8462
# Epoch 13/20
# 225/225 [==============================] - 1s 6ms/step - loss: 0.1175 - accuracy: 0.9572 - val_loss: 0.4207 - val_accuracy: 0.8427
# Epoch 14/20
# 225/225 [==============================] - 2s 8ms/step - loss: 0.1135 - accuracy: 0.9588 - val_loss: 0.4256 - val_accuracy: 0.8435
# Epoch 15/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.1104 - accuracy: 0.9593 - val_loss: 0.4334 - val_accuracy: 0.8435
# Epoch 16/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.1056 - accuracy: 0.9610 - val_loss: 0.4409 - val_accuracy: 0.8423
# Epoch 17/20
# 225/225 [==============================] - 1s 7ms/step - loss: 0.1025 - accuracy: 0.9644 - val_loss: 0.4419 - val_accuracy: 0.8419
# Epoch 18/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0992 - accuracy: 0.9660 - val_loss: 0.4504 - val_accuracy: 0.8410
# Epoch 19/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0962 - accuracy: 0.9689 - val_loss: 0.4542 - val_accuracy: 0.8408
# Epoch 20/20
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0943 - accuracy: 0.9679 - val_loss: 0.4610 - val_accuracy: 0.8392

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs=range(len(acc))
plt.plot(epochs, acc, 'r', 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', 'Validation Accuracy')
plt.title('Training and validation accuracy')
plt.figure()
plt.plot(epochs, loss, 'r', 'Training Loss')
plt.plot(epochs, val_loss, 'b', 'Validation Loss')
plt.title('Training and validation loss')
plt.figure()

# %%
predict_sentences = tokenizer.texts_to_sequences([
"Gamesnya babi",
"Semakin mantep Update Sumeru. Semua dari update ini saya Suka Semua dari segi Design Charnya, Viewnya, Dan juga Story nya Epic PARAAHHH",
"jelek banget",
"bagus"])
predict_padded = pad_sequences(predict_sentences, maxlen=max_length)

model.predict(predict_padded)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[0.5474753 ],
#        [0.9980272 ],
#        [0.18486309],
#        [0.9870987 ]], dtype=float32)
